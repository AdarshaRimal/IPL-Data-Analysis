# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches = pd.read_csv('matches.csv')
deleveries = pd.read_csv('deliveries.csv')

# %% [markdown]
# # Understanding Data

# %% [markdown]
# ## How big is the data?

# %%
matches.shape
# Out:
# (1095, 20)

# %%
deleveries.shape
# Out:
# (260920, 17)

# %% [markdown]
# ## How does the data looks like?

# %%
matches.sample(7)
# Out:
#           id   season            city        date match_type player_of_match  \
# 214   501238     2011           Delhi  2011-05-02     League  P Parameswaran
# 667  1136592     2018           Delhi  2018-05-02     League         RR Pant
# 191   501214     2011         Kolkata  2011-04-17     League        L Balaji
# 169   419160  2009/10           Delhi  2010-04-18     League       A Symonds
# 465   829719     2015       Bangalore  2015-04-13     League       DA Warner
# 732  1178412     2019           Delhi  2019-04-20     League         SS Iyer
# 80    392205     2009  Port Elizabeth  2009-05-02     League       YK Pathan
#
#                      venue                        team1                 team2  \
# 214       Feroz Shah Kotla             Delhi Daredevils  Kochi Tuskers Kerala
# 667   Arun Jaitley Stadium             Delhi Daredevils      Rajasthan Royals
# 191           Eden Gardens        Kolkata Knight Riders      Rajasthan Royals
# 169       Feroz Shah Kotla             Delhi Daredevils       Deccan Chargers
# 465  M Chinnaswamy Stadium  Royal Challengers Bangalore   Sunrisers Hyderabad
# 732   Arun Jaitley Stadium              Kings XI Punjab        Delhi Capitals
# 80        St George's Park              Deccan Chargers      Rajasthan Royals
#
#                toss_winner toss_decision                 winner   result  \
# 214   Kochi Tuskers Kerala         field   Kochi Tuskers Kerala  wickets
# 667       Rajasthan Royals         field       Delhi Daredevils     runs
# 191  Kolkata Knight Riders         field  Kolkata Knight Riders  wickets
# 169        Deccan Chargers           bat        Deccan Chargers     runs
# 465    Sunrisers Hyderabad         field    Sunrisers Hyderabad  wickets
# 732         Delhi Capitals         field         Delhi Capitals  wickets
# 80         Deccan Chargers           bat       Rajasthan Royals  wickets
#
#      result_margin  target_runs  target_overs super_over method  \
# 214            7.0        141.0          20.0          N    NaN
# 667            4.0        151.0          12.0          N    D/L
# 191            8.0         82.0          20.0          N    NaN
# 169           11.0        146.0          20.0          N    NaN
# 465            8.0        167.0          20.0          N    NaN
# 732            5.0        164.0          20.0          N    NaN
# 80             3.0        142.0          20.0          N    NaN
#
#            umpire1         umpire2
# 214      Asad Rauf      SL Shastri
# 667      CK Nandan       VK Sharma
# 191      Aleem Dar       RB Tiffin
# 169    BR Doctrove     SK Tarapore
# 465   RM Deshpande  RK Illingworth
# 732  C Shamshuddin       UV Gandhe
# 80        S Asnani      BG Jerling

# %%
deleveries.sample(7)
# Out:
#         match_id  inning                 batting_team  \
# 132850    980987       2                Gujarat Lions
# 102245    733995       1               Mumbai Indians
# 64284     548330       1          Chennai Super Kings
# 22684     392221       2  Royal Challengers Bangalore
# 36205     419143       1              Kings XI Punjab
# 78657     598007       1              Kings XI Punjab
# 168655   1175371       2          Sunrisers Hyderabad
#
#                        bowling_team  over  ball         batter      bowler  \
# 132850  Royal Challengers Bangalore     3     1      RA Jadeja   S Aravind
# 102245          Chennai Super Kings    19     4    CJ Anderson   IC Pandey
# 64284                 Pune Warriors     7     3    S Badrinath  AD Mathews
# 22684         Kolkata Knight Riders    17     5    LRPL Taylor    I Sharma
# 36205              Rajasthan Royals    15     1      RS Bopara    FY Fazal
# 78657           Chennai Super Kings    18     3        P Kumar   CH Morris
# 168655               Delhi Capitals    17     1  Mohammad Nabi   CH Morris
#
#          non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 132850   BB McCullum             1           0           1         NaN
# 102245       AP Tare             2           0           2         NaN
# 64284   F du Plessis             1           0           1         NaN
# 22684     MV Boucher             1           0           1         NaN
# 36205      IK Pathan             1           0           1         NaN
# 78657        P Awana             0           0           0         NaN
# 168655     YK Pathan             0           0           0         NaN
#
#         is_wicket player_dismissed dismissal_kind fielder
# 132850          0              NaN            NaN     NaN
# 102245          0              NaN            NaN     NaN
# 64284           0              NaN            NaN     NaN
# 22684           0              NaN            NaN     NaN
# 36205           0              NaN            NaN     NaN
# 78657           0              NaN            NaN     NaN
# 168655          0              NaN            NaN     NaN

# %% [markdown]
# ## What is the data type of features (columns)

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
deleveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %% [markdown]
# ## Are there any missing values ?

# %%
matches.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %% [markdown]
# we can see the column city , result_margin , target_runs, target_overs , method has null values

# %%
deleveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %% [markdown]
# here also extras_type ,player_dismissed ,dismissal_kind ,fielder are missing

# %% [markdown]
# ## how does the data look like mathematically ??

# %%
matches.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
deleveries.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       1.000000       0.000000
# 75%         1.000000       0.000000       1.000000       0.000000
# max         6.000000       7.000000       7.000000       1.000000

# %% [markdown]
# ## Are there any duplicated values ??

# %%
matches.duplicated().sum()
# Out:
# 0

# %%
deleveries.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## how is the correlation between columns ?? imp

# %%
matches.corr()['result_margin']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 matches.corr()['result_margin']
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '2007/08'

# %%
numeric_matches = matches.select_dtypes(include='number')
correlation = numeric_matches.corr()['result_margin']
correlation
# Out:
# id              -0.006853
# result_margin    1.000000
# target_runs      0.395120
# target_overs     0.030970
# Name: result_margin, dtype: float64

# %%
numeric_deleveries = deleveries.select_dtypes(include='number')
corr = numeric_deleveries.corr()['batsman_runs']
corr
# Out:
# match_id        0.036742
# inning         -0.005690
# over            0.080040
# ball            0.004391
# batsman_runs    1.000000
# extra_runs     -0.142079
# total_runs      0.977934
# is_wicket      -0.171751
# Name: batsman_runs, dtype: float64

# %%
# lets do some univariate anlysis

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize = (15,10))
sns.countplot(data=matches, x = 'city')
plt.xticks(rotation=-70)
plt.show()

# %%
matches['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15,10))
sns.countplot(data=matches, x = 'venue')
plt.xticks(rotation=-70)
plt.show()

# %%
matches['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# MA Chidambaram Stadium, Chepauk, Chennai                                 28
# Narendra Modi Stadium, Ahmedabad                                         24
# Maharashtra Cricket Association Stadium                                  22
# Dr DY Patil Sports Academy, Mumbai                                       20
# Brabourne Stadium, Mumbai                                                17
# Dr DY Patil Sports Academy                                               17
# Eden Gardens, Kolkata                                                    16
# Subrata Roy Sahara Stadium                                               16
# Arun Jaitley Stadium, Delhi                                              16
# Rajiv Gandhi International Stadium                                       15
# M.Chinnaswamy Stadium                                                    15
# Kingsmead                                                                15
# Arun Jaitley Stadium                                                     14
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    14
# M Chinnaswamy Stadium, Bengaluru                                         14
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     13
# Maharashtra Cricket Association Stadium, Pune                            13
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium                      13
# SuperSport Park                                                          12
# Sardar Patel Stadium, Motera                                             12
# Punjab Cricket Association IS Bindra Stadium, Mohali                     11
# Sawai Mansingh Stadium, Jaipur                                           10
# Saurashtra Cricket Association Stadium                                   10
# Brabourne Stadium                                                        10
# Punjab Cricket Association IS Bindra Stadium                             10
# Himachal Pradesh Cricket Association Stadium                              9
# MA Chidambaram Stadium                                                    9
# Holkar Cricket Stadium                                                    9
# New Wanderers Stadium                                                     8
# Zayed Cricket Stadium, Abu Dhabi                                          8
# JSCA International Stadium Complex                                        7
# Barabati Stadium                                                          7
# St George's Park                                                          7
# Newlands                                                                  7
# Shaheed Veer Narayan Singh International Stadium                          6
# Nehru Stadium                                                             5
# Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh          5
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur        5
# Green Park                                                                4
# Himachal Pradesh Cricket Association Stadium, Dharamsala                  4
# Vidarbha Cricket Association Stadium, Jamtha                              3
# De Beers Diamond Oval                                                     3
# Buffalo Park                                                              3
# Barsapara Cricket Stadium, Guwahati                                       3
# OUTsurance Oval                                                           2
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam        2
# Name: count, dtype: int64

# %%
result_count = matches['result'].value_counts()
result_count
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
plt.pie(result_count,labels=result_count.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25a1ac9dcd0>,
#   <matplotlib.patches.Wedge at 0x25a1963f6b0>,
#   <matplotlib.patches.Wedge at 0x25a1ac0f620>,
#   <matplotlib.patches.Wedge at 0x25a1ac0dd30>],
#  [Text(-0.09613339396061713, 1.0957912075599132, 'wickets'),
#   Text(0.03628689157184371, -1.0994013195826415, 'runs'),
#   Text(1.097393350313619, -0.07568245957585214, 'tie'),
#   Text(1.0998868237743198, -0.015778938102376395, 'no result')],
#  [Text(-0.05243639670579115, 0.5977042950326799, '52.8%'),
#   Text(0.019792849948278384, -0.5996734470450771, '45.5%'),
#   Text(0.5985781910801559, -0.04128134158682844, '1.3%'),
#   Text(0.5999382675132653, -0.008606693510387124, '0.5%')])

# %%
matches['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
plt.hist(matches['target_runs'],bins = 20)
# Out:
# (array([  5.,   4.,   8.,   9.,  16.,  31.,  54.,  94., 134., 181., 170.,
#         147., 107.,  64.,  35.,  20.,   5.,   3.,   3.,   2.]),
#  array([ 43.  ,  55.25,  67.5 ,  79.75,  92.  , 104.25, 116.5 , 128.75,
#         141.  , 153.25, 165.5 , 177.75, 190.  , 202.25, 214.5 , 226.75,
#         239.  , 251.25, 263.5 , 275.75, 288.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.boxplot(data = matches, x = 'target_runs')
# Out:
# <Axes: xlabel='target_runs'>
